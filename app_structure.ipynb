# %% [markdown]
# # Code Base Structure Explanation

# %% [markdown]
# ## Streamlit UI
#
# ### Begin
# with the set_page_config method
# ### Ends
# with execute report method

# %%
# set the page config
st.set_page_config(layout="wide")

#...

with col2row2:
        with st.container(height=ROW_HIGHT):
            st.write("### AI Generated Report")

            # execute the code
            exec(reporting_code)
